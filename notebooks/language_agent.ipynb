# %%
import sys
sys.path.insert(0, "../src/")
from dotenv import load_dotenv
from language_agent import build_graph

load_dotenv()
# Out:
# True

# %%
language_workflow = build_graph()

response = language_workflow.invoke(
    {
        "user_message": "I want to exercise my reading skills by reading the latest news from Iran.",
        "user_level": "A2",
        "target_language": "Italian"}
    )

# %%
from pprint import pprint
pprint(response)
# Out:
# {'agent_output': AgentOutput(agent_name='reading_agent', result="Ecco un breve testo in italiano sul tema delle ultime notizie dall'Iran, adatto per il livello A2:\n\nNegli ultimi giorni, ci sono stati eventi importanti in Iran. L'Iran ha abbattuto un aereo da combattimento degli Stati Uniti, il F-15E Strike Eagle. Questo è un fatto raro, poiché è la prima volta in decenni che un aereo americano è stato colpito in combattimento. Questa notizia ha attirato l'attenzione dei media in tutto il mondo.\n\nInoltre, ci sono stati attacchi a strutture petrolifere in Kuwait. Gli Stati Uniti e Israele hanno avviato attacchi contro l'Iran e ci sono preoccupazioni per la stabilità nella regione. I leader politici stanno discutendo su come rispondere a questa situazione difficile.\n\nLa crisi in Iran continua a evolversi e molte persone stanno seguendo gli aggiornamenti. È importante restare informati su ciò che accade nel mondo, specialmente in una regione così significativa."),
# ...

# %%
language_workflow = build_graph()

response = language_workflow.invoke(
    {
        "user_message": "I want to listen to Italian music.",
        "user_level": "A2",
        "target_language": "Italian"}
    )

# %%
from pprint import pprint
pprint(response)
# Out:
# {'classification': Classification(classification='unknown'),
#  'response': "I'm sorry, I don't know how to answer that question. I can only "
#              'help you with grammar and reading exercises.',
#  'target_language': 'Italian',
#  'user_level': 'A2',
#  'user_message': 'I want to listen to Italian music.'}
